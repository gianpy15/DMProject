# %%
import os
os.chdir('./..')

# %%
import src.data as data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import time
import src.utility as utils

# %%
bs=data.base_structure_hours()
# Out:
# base structure loaded in: 0.0 s
#
# shape of the dataframe is: (5298840, 3)

# %%
bs
# Out:
#                 DATETIME_UTC  KEY    KM
# 0        2018-09-01 00:00:00    0   333
# 1        2018-09-01 00:00:00    0   337
# 2        2018-09-01 00:00:00    0   342
# 3        2018-09-01 00:00:00    0   343
# 4        2018-09-01 00:00:00    0   357
# 5        2018-09-01 00:00:00    0   385
# 6        2018-09-01 00:00:00    0   407
# 7        2018-09-01 00:00:00    0   411
# 8        2018-09-01 00:00:00    0   423
# 9        2018-09-01 00:00:00    0   443
# 10       2018-09-01 00:00:00    0   454
# 11       2018-09-01 00:00:00    0   488
# 12       2018-09-01 00:00:00    0   520
# 13       2018-09-01 00:00:00    1  1480
# 14       2018-09-01 00:00:00    1  1512
# 15       2018-09-01 00:00:00    1  1546
# 16       2018-09-01 00:00:00    1  1557
# 17       2018-09-01 00:00:00    1  1577
# 18       2018-09-01 00:00:00    1  1589
# 19       2018-09-01 00:00:00    1  1593
# 20       2018-09-01 00:00:00    1  1615
# 21       2018-09-01 00:00:00    1  1643
# ...

# %%
a = bs[['DATETIME_UTC']].drop_duplicates()

# %%
# Out:
#                 DATETIME_UTC
# 0        2018-09-01 00:00:00
# 1795     2018-09-01 01:00:00
# 3590     2018-09-01 02:00:00
# 5385     2018-09-01 03:00:00
# 7180     2018-09-01 04:00:00
# 8975     2018-09-01 05:00:00
# 10770    2018-09-01 06:00:00
# 12565    2018-09-01 07:00:00
# 14360    2018-09-01 08:00:00
# 16155    2018-09-01 09:00:00
# 17950    2018-09-01 10:00:00
# 19745    2018-09-01 11:00:00
# 21540    2018-09-01 12:00:00
# 23335    2018-09-01 13:00:00
# 25130    2018-09-01 14:00:00
# 26925    2018-09-01 15:00:00
# 28720    2018-09-01 16:00:00
# 30515    2018-09-01 17:00:00
# 32310    2018-09-01 18:00:00
# 34105    2018-09-01 19:00:00
# 35900    2018-09-01 20:00:00
# 37695    2018-09-01 21:00:00
# 39490    2018-09-01 22:00:00
# 41285    2018-09-01 23:00:00
# 43080    2018-09-02 00:00:00
# 44875    2018-09-02 01:00:00
# 46670    2018-09-02 02:00:00
# 48465    2018-09-02 03:00:00
# 50260    2018-09-02 04:00:00
# 52055    2018-09-02 05:00:00
# ...                      ...
# ...
