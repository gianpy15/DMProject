# %%
#Extra function created to help me solve some problems
import re

def natural_sort(l): 
    convert = lambda text: int(text) if text.isdigit() else text.lower() 
    alphanum_key = lambda key: [ convert(c) for c in re.split('([0-9]+)', key) ] 
    return sorted(l, key = alphanum_key)

def get_first_nbr_from_str(input_str):
    if not input_str and not isinstance(input_str, str):
        return 0
    out_number = ''
    for ele in input_str:
        if (ele == '.' and '.' not in out_number) or ele.isdigit():
            out_number += ele
        elif out_number:
            break
    return int(out_number)

# %% [markdown]
# # Giorno 2

# %%
import os
os.chdir('./..')
import pandas as pd
import numpy as np
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
_BASE_PATH = 'resources/dataset/originals'

from src import data
from src.preprocessing.distances import preprocess

# %%
preprocess()
distances= data.distances_proprocessed()
distances
# Out:
# caching distances
#
# distances loaded in: 0.082 s
#
# shape of the dataframe is: (41054, 2)
# caching distances
#
# distances loaded in: 0.0844 s
#
# shape of the dataframe is: (41046, 3)
#                                                 STATIONS   KEY    KM
# 0      STATION_29,10.0;STATION_37,19.0;STATION_36,40....   278   662
# 1      STATION_29,10.0;STATION_37,19.0;STATION_36,40....   278   663
# 2      STATION_29,10.0;STATION_37,19.0;STATION_36,40....   278   664
# 3      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   665
# 4      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   666
# 5      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   667
# 6      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   668
# 7      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   669
# 8      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   670
# 9      STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   671
# 10     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   672
# 11     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   673
# 12     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   674
# 13     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   675
# 14     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   676
# 15     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   677
# 16     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   678
# 17     STATION_29,6.0;STATION_37,17.0;STATION_36,44.0...   278   679
# 18     STATION_29,7.0;STATION_37,17.0;STATION_28,35.0...   278   680
# 19     STATION_29,7.0;STATION_37,17.0;STATION_28,35.0...   278   681
# 20     STATION_29,7.0;STATION_37,17.0;STATION_28,35.0...   278   682
# 21     STATION_29,7.0;STATION_37,17.0;STATION_28,35.0...   278   683
# 22     STATION_29,7.0;STATION_37,17.0;STATION_28,35.0...   278   684
# 23     STATION_29,7.0;STATION_37,17.0;STATION_28,35.0...   278   685
# 24     STATION_29,8.0;STATION_37,16.0;STATION_28,34.0...   278   686
# 25     STATION_29,8.0;STATION_37,16.0;STATION_28,34.0...   278   687
# 26     STATION_29,9.0;STATION_37,16.0;STATION_28,34.0...   278   688
# 27     STATION_33,54.0;STATION_29,64.0;STATION_37,73....   280   593
# 28     STATION_33,52.0;STATION_29,64.0;STATION_37,73....   280   594
# 29     STATION_33,52.0;STATION_29,64.0;STATION_37,73....   280   595
# ...                                                  ...   ...   ...
# 41016  STATION_22,17.0;STATION_27,91.0;STATION_23,124...   107  1798
# 41017  STATION_61,22.0;STATION_78,53.0;STATION_80,55....   530  1615
# 41018  STATION_61,22.0;STATION_78,53.0;STATION_80,55....   530  1614
# 41019  STATION_61,20.0;STATION_78,53.0;STATION_65,56....   530  1613
# 41020  STATION_89,8.0;STATION_54,30.0;STATION_50,69.0...    40  1929
# 41021  STATION_89,8.0;STATION_54,30.0;STATION_50,69.0...    40  1928
# 41022  STATION_89,9.0;STATION_54,31.0;STATION_50,70.0...    40  1927
# 41023  STATION_18,52.0;STATION_21,122.0;STATION_13,13...   406  1814
# 41024  STATION_18,52.0;STATION_21,122.0;STATION_13,13...   406  1813
# 41025  STATION_18,49.0;STATION_21,119.0;STATION_13,13...   406  1812
# 41026  STATION_18,49.0;STATION_21,119.0;STATION_13,13...   406  1811
# 41027  STATION_18,49.0;STATION_21,119.0;STATION_13,13...   406  1810
# 41028  STATION_18,49.0;STATION_21,119.0;STATION_13,13...   406  1809
# 41029  STATION_18,48.0;STATION_21,118.0;STATION_13,13...   406  1808
# 41030  STATION_18,48.0;STATION_21,118.0;STATION_13,13...   406  1807
# 41031  STATION_18,48.0;STATION_21,118.0;STATION_13,13...   406  1806
# 41032  STATION_18,48.0;STATION_21,118.0;STATION_13,13...   406  1805
# 41033  STATION_18,46.0;STATION_21,116.0;STATION_13,13...   406  1804
# 41034  STATION_18,46.0;STATION_21,116.0;STATION_13,13...   406  1803
# 41035  STATION_18,46.0;STATION_21,116.0;STATION_13,13...   406  1802
# 41036  STATION_0,31.0;STATION_3,51.0;STATION_69,82.0;...   555  1494
# 41037  STATION_0,31.0;STATION_3,51.0;STATION_69,82.0;...   555  1493
# 41038  STATION_0,30.0;STATION_3,50.0;STATION_69,81.0;...   555  1492
# 41039  STATION_0,30.0;STATION_3,50.0;STATION_69,81.0;...   555  1491
# 41040  STATION_0,30.0;STATION_3,49.0;STATION_69,81.0;...   555  1490
# 41041  STATION_0,30.0;STATION_3,49.0;STATION_69,81.0;...   555  1489
# 41042  STATION_15,7.0;STATION_19,15.0;STATION_21,29.0...  None  1628
# 41043  STATION_15,7.0;STATION_19,16.0;STATION_21,30.0...  None  1627
# 41044  STATION_18,68.0;STATION_21,138.0;STATION_13,15...    73  1594
# 41045  STATION_18,68.0;STATION_21,138.0;STATION_13,15...    73  1593
#
# [41046 rows x 3 columns]

# %%
bs_hours=data.base_structure_hours()
base_structure_df =bs_hours
base_structure_df.head()
# Out:
# caching base structure
#
# base structure loaded in: 3.0668 s
#
# shape of the dataframe is: (5298840, 3)
#   DATETIME_UTC  KEY   KM
# 0   2018-09-01    0  333
# 1   2018-09-01    0  337
# 2   2018-09-01    0  342
# 3   2018-09-01    0  343
# 4   2018-09-01    0  357

# %%
weather_train_df = data.weather_original()

#lavoro su uno slice di 1M
base_structure_df ["WEATHER"]=""
base_structure_df ["DISTANCE"]=np.NaN

#weather_train_df1=weather_train_df.set_index(["ID","DATETIME_UTC"])
# Out:
# caching resources/dataset/originals/weather_train.csv.gz

# %%
stations=weather_train_df[["ID"]].drop_duplicates()
stations["dummy"]=0

# %%
times=base_structure_df[["DATETIME_UTC"]].drop_duplicates()
times["dummy"]=0

# %%
bs_2=pd.merge(stations,times)
bs_2=bs_2.drop("dummy",axis=1)
bs_2
# Out:
#                 ID        DATETIME_UTC
# 0        STATION_7 2018-09-01 00:00:00
# 1        STATION_7 2018-09-01 01:00:00
# 2        STATION_7 2018-09-01 02:00:00
# 3        STATION_7 2018-09-01 03:00:00
# 4        STATION_7 2018-09-01 04:00:00
# 5        STATION_7 2018-09-01 05:00:00
# 6        STATION_7 2018-09-01 06:00:00
# 7        STATION_7 2018-09-01 07:00:00
# 266689  STATION_18 2019-01-01 17:00:00          NaN              NaN
# 266690  STATION_18 2019-01-01 18:00:00          NaN              NaN
# 266691  STATION_18 2019-01-01 19:00:00          NaN              NaN
# 266692  STATION_18 2019-01-01 20:00:00          NaN              NaN
# 266693  STATION_18 2019-01-01 21:00:00          NaN              NaN
# 266694  STATION_18 2019-01-01 22:00:00          NaN              NaN
# 266695  STATION_18 2019-01-01 23:00:00          NaN              NaN
#
#         MIN_TEMPERATURE       WEATHER
# 0                   NaN           NaN
# 1                   NaN           NaN
# 2                   NaN           NaN
# 3                   NaN           NaN
# 4                   NaN           NaN
# 5                   NaN           NaN
# 6                   NaN           NaN
# 7                   NaN           NaN
# 8                   NaN           NaN
# 9                   NaN           NaN
# 10                 22.0  Quasi Sereno
# 11                  NaN           NaN
# 12                 22.0  Quasi Sereno
# 13                  NaN           NaN
# 14                  NaN           NaN
# 15                  NaN           NaN
# 16                  NaN           NaN
# 17                  NaN           NaN
# 18                  NaN           NaN
# 19                  NaN           NaN
# 20                  NaN           NaN
# 21                  NaN           NaN
# 22                 22.0  Quasi Sereno
# 23                  NaN           NaN
# 24                 22.0  Quasi Sereno
# 25                  NaN           NaN
# 26                  NaN           NaN
# 27                  NaN           NaN
# 28                  NaN           NaN
# 29                  NaN           NaN
# ...                 ...           ...
# 266666              NaN           NaN
# 266667              NaN           NaN
# 266668              NaN           NaN
# 266669              NaN           NaN
# 266670              NaN           NaN
# 266671              NaN           NaN
# 266672              NaN           NaN
# 266673              NaN           NaN
# 266674              NaN           NaN
# 266675              NaN           NaN
# 266676              NaN           NaN
# 266677              NaN           NaN
# 266678              NaN           NaN
# 266679              NaN           NaN
# 266680              NaN           NaN
# 266681              NaN           NaN
# 266682              NaN           NaN
# 266683              NaN           NaN
# 266684              NaN           NaN
# 266685              NaN           NaN
# 266686              NaN           NaN
# 266687              NaN           NaN
# 266688              NaN           NaN
# 266689              NaN           NaN
# 266690              NaN           NaN
# 266691              NaN           NaN
# 266692              NaN           NaN
# 266693              NaN           NaN
# 266694              NaN           NaN
# 266695              NaN           NaN
#
# [266696 rows x 6 columns]

# %%
#Creazione Dizionario per le distanze
distances_dict = dict()
d=list(distances.groupby(by=["KEY","KM"]).groups.keys())
for x in tqdm(d):
    distances_dict[x] =list(map(lambda x: x.split(','), distances.loc[(distances['KEY']==x[0]) & 
                                                             (distances['KM']==x[1])].STATIONS.values[0].split(";")))
# Out:
# HBox(children=(IntProgress(value=0, max=41046), HTML(value='')))

# %%
weather_train_df2=weather_train_df2.set_index(["ID","DATETIME_UTC"])
weather_train_df2
# Out:
#                                 TEMPERATURE  MAX_TEMPERATURE  MIN_TEMPERATURE  \
# ID         DATETIME_UTC
# STATION_7  2018-09-01 00:00:00          NaN              NaN              NaN
#            2018-09-01 01:00:00          NaN              NaN              NaN
#            2018-09-01 02:00:00          NaN              NaN              NaN
#            2018-09-01 03:00:00          NaN              NaN              NaN
#            2018-09-01 04:00:00          NaN              NaN              NaN
#            2018-09-01 05:00:00          NaN              NaN              NaN
# STATION_7  2018-09-01 00:00:00           NaN
#            2018-09-01 01:00:00           NaN
#            2018-09-01 02:00:00           NaN
#            2018-09-01 03:00:00           NaN
#            2018-09-01 04:00:00           NaN
#            2018-09-01 05:00:00           NaN
#            2018-09-01 06:00:00           NaN
#            2018-09-01 07:00:00           NaN
#            2018-09-01 08:00:00           NaN
#            2018-09-01 09:00:00           NaN
#            2018-09-01 10:00:00  Quasi Sereno
#            2018-09-01 11:00:00           NaN
#            2018-09-01 12:00:00  Quasi Sereno
#            2018-09-01 13:00:00           NaN
#            2018-09-01 14:00:00           NaN
#            2018-09-01 15:00:00           NaN
#            2018-09-01 16:00:00           NaN
#            2018-09-01 17:00:00           NaN
#            2018-09-01 18:00:00           NaN
#            2018-09-01 19:00:00           NaN
#            2018-09-01 20:00:00           NaN
#            2018-09-01 21:00:00           NaN
#            2018-09-01 22:00:00  Quasi Sereno
#            2018-09-01 23:00:00           NaN
#            2018-09-02 00:00:00  Quasi Sereno
#            2018-09-02 01:00:00           NaN
#            2018-09-02 02:00:00           NaN
#            2018-09-02 03:00:00           NaN
#            2018-09-02 04:00:00           NaN
#            2018-09-02 05:00:00           NaN
# ...                                      ...
# STATION_18 2018-12-31 18:00:00           NaN
#            2018-12-31 19:00:00           NaN
#            2018-12-31 20:00:00           NaN
#            2018-12-31 21:00:00           NaN
#            2018-12-31 22:00:00           NaN
#            2018-12-31 23:00:00           NaN
#            2019-01-01 00:00:00           NaN
#            2019-01-01 01:00:00           NaN
#            2019-01-01 02:00:00           NaN
#            2019-01-01 03:00:00           NaN
#            2019-01-01 04:00:00           NaN
#            2019-01-01 05:00:00           NaN
#            2019-01-01 06:00:00           NaN
#            2019-01-01 07:00:00           NaN
#            2019-01-01 08:00:00           NaN
#            2019-01-01 09:00:00           NaN
#            2019-01-01 10:00:00           NaN
#            2019-01-01 11:00:00           NaN
#            2019-01-01 12:00:00           NaN
#            2019-01-01 13:00:00           NaN
#            2019-01-01 14:00:00           NaN
#            2019-01-01 15:00:00           NaN
#            2019-01-01 16:00:00           NaN
#            2019-01-01 17:00:00           NaN
#            2019-01-01 18:00:00           NaN
#            2019-01-01 19:00:00           NaN
#            2019-01-01 20:00:00           NaN
#            2019-01-01 21:00:00           NaN
#            2019-01-01 22:00:00           NaN
#            2019-01-01 23:00:00           NaN
#
# [266696 rows x 4 columns]

# %%
import math

base_structure_df ["WEATHER"]=""
base_structure_df ["DISTANCE"]=np.NaN



for i,row in tqdm(base_structure_df.iterrows()):
    date=row.DATETIME_UTC
    
    stations=distances_dict[(str(row.KEY),row.KM)]
    weather = np.NaN
    it=0
    
    while not isinstance(weather, str):
        #get station and dist from dict
        station=stations[it][0]
        distance=stations[it][1]

        weather=weather_train_df2.loc[(station,date)].WEATHER.values[0]
        it+=1
        if it>= len(stations):
            print("NON PRESENTE")
            print (row)
            break
    
    base_structure_df.at[i,'WEATHER'] = weather
    base_structure_df.at[i,'DISTANCE'] = distance
# Out:
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: PerformanceWarning: indexing past lexsort depth may impact performance.
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              333
# WEATHER
# DISTANCE                        NaN
# Name: 1795, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              337
# WEATHER
# DISTANCE                        NaN
# Name: 1796, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              342
# WEATHER
# DISTANCE                        NaN
# Name: 1797, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              343
# WEATHER
# DISTANCE                        NaN
# Name: 1798, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              357
# WEATHER
# DISTANCE                        NaN
# Name: 1799, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              385
# WEATHER
# DISTANCE                        NaN
# Name: 1800, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              407
# WEATHER
# DISTANCE                        NaN
# Name: 1801, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              411
# WEATHER
# DISTANCE                        NaN
# Name: 1802, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              423
# WEATHER
# DISTANCE                        NaN
# Name: 1803, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              443
# WEATHER
# DISTANCE                        NaN
# Name: 1804, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              454
# WEATHER
# DISTANCE                        NaN
# Name: 1805, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              488
# WEATHER
# DISTANCE                        NaN
# Name: 1806, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               0
# KM                              520
# WEATHER
# DISTANCE                        NaN
# Name: 1807, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1480
# WEATHER
# DISTANCE                        NaN
# Name: 1808, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1512
# WEATHER
# DISTANCE                        NaN
# Name: 1809, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1546
# WEATHER
# DISTANCE                        NaN
# Name: 1810, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1557
# WEATHER
# DISTANCE                        NaN
# Name: 1811, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1577
# WEATHER
# DISTANCE                        NaN
# Name: 1812, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1589
# WEATHER
# DISTANCE                        NaN
# Name: 1813, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1593
# WEATHER
# DISTANCE                        NaN
# Name: 1814, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1615
# WEATHER
# DISTANCE                        NaN
# Name: 1815, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1643
# WEATHER
# DISTANCE                        NaN
# Name: 1816, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1657
# WEATHER
# DISTANCE                        NaN
# Name: 1817, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1658
# WEATHER
# DISTANCE                        NaN
# Name: 1818, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1663
# WEATHER
# DISTANCE                        NaN
# Name: 1819, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                               1
# KM                             1667
# WEATHER
# DISTANCE                        NaN
# Name: 1820, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              10
# KM                               79
# WEATHER
# DISTANCE                        NaN
# Name: 1821, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             100
# KM                              577
# WEATHER
# DISTANCE                        NaN
# Name: 1822, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             101
# KM                             1423
# WEATHER
# DISTANCE                        NaN
# Name: 1823, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             102
# KM                              837
# WEATHER
# DISTANCE                        NaN
# Name: 1824, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             102
# KM                              877
# WEATHER
# DISTANCE                        NaN
# Name: 1825, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             102
# KM                              918
# WEATHER
# DISTANCE                        NaN
# Name: 1826, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             102
# KM                              933
# WEATHER
# DISTANCE                        NaN
# Name: 1827, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             102
# KM                              949
# WEATHER
# DISTANCE                        NaN
# Name: 1828, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             103
# KM                             1051
# WEATHER
# DISTANCE                        NaN
# Name: 1829, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             103
# KM                             1067
# WEATHER
# DISTANCE                        NaN
# Name: 1830, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             103
# KM                             1082
# WEATHER
# DISTANCE                        NaN
# Name: 1831, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             103
# KM                             1123
# WEATHER
# DISTANCE                        NaN
# Name: 1832, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             103
# KM                             1163
# WEATHER
# DISTANCE                        NaN
# Name: 1833, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             104
# KM                              719
# WEATHER
# DISTANCE                        NaN
# Name: 1834, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             104
# KM                              749
# WEATHER
# DISTANCE                        NaN
# Name: 1835, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             105
# KM                             1251
# WEATHER
# DISTANCE                        NaN
# Name: 1836, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             105
# KM                             1281
# WEATHER
# DISTANCE                        NaN
# Name: 1837, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             106
# KM                              190
# WEATHER
# DISTANCE                        NaN
# Name: 1838, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             107
# KM                             1810
# WEATHER
# DISTANCE                        NaN
# Name: 1839, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             108
# KM                              108
# WEATHER
# DISTANCE                        NaN
# Name: 1840, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             108
# KM                              148
# WEATHER
# DISTANCE                        NaN
# Name: 1841, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             108
# KM                              175
# WEATHER
# DISTANCE                        NaN
# Name: 1842, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             108
# KM                              210
# WEATHER
# DISTANCE                        NaN
# Name: 1843, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             108
# KM                              253
# WEATHER
# DISTANCE                        NaN
# Name: 1844, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             109
# KM                             1747
# WEATHER
# DISTANCE                        NaN
# Name: 1845, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             109
# KM                             1790
# WEATHER
# DISTANCE                        NaN
# Name: 1846, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             109
# KM                             1825
# WEATHER
# DISTANCE                        NaN
# Name: 1847, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             109
# KM                             1852
# WEATHER
# DISTANCE                        NaN
# Name: 1848, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             109
# KM                             1892
# WEATHER
# DISTANCE                        NaN
# Name: 1849, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              11
# KM                             1921
# WEATHER
# DISTANCE                        NaN
# Name: 1850, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             110
# KM                              613
# WEATHER
# DISTANCE                        NaN
# Name: 1851, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             110
# KM                              661
# WEATHER
# DISTANCE                        NaN
# Name: 1852, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             111
# KM                             1339
# WEATHER
# DISTANCE                        NaN
# Name: 1853, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             111
# KM                             1387
# WEATHER
# DISTANCE                        NaN
# Name: 1854, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             112
# KM                              590
# WEATHER
# DISTANCE                        NaN
# Name: 1855, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             112
# KM                              610
# WEATHER
# DISTANCE                        NaN
# Name: 1856, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             112
# KM                              644
# WEATHER
# DISTANCE                        NaN
# Name: 1857, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             113
# KM                             1356
# WEATHER
# DISTANCE                        NaN
# Name: 1858, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             113
# KM                             1390
# WEATHER
# DISTANCE                        NaN
# Name: 1859, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             113
# KM                             1410
# WEATHER
# DISTANCE                        NaN
# Name: 1860, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              175
# WEATHER
# DISTANCE                        NaN
# Name: 1861, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              215
# WEATHER
# DISTANCE                        NaN
# Name: 1862, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              229
# WEATHER
# DISTANCE                        NaN
# Name: 1863, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              272
# WEATHER
# DISTANCE                        NaN
# Name: 1864, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              297
# WEATHER
# DISTANCE                        NaN
# Name: 1865, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              308
# WEATHER
# DISTANCE                        NaN
# Name: 1866, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              327
# WEATHER
# DISTANCE                        NaN
# Name: 1867, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              346
# WEATHER
# DISTANCE                        NaN
# Name: 1868, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              358
# WEATHER
# DISTANCE                        NaN
# Name: 1869, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             114
# KM                              377
# WEATHER
# DISTANCE                        NaN
# Name: 1870, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1623
# WEATHER
# DISTANCE                        NaN
# Name: 1871, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1642
# WEATHER
# DISTANCE                        NaN
# Name: 1872, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1654
# WEATHER
# DISTANCE                        NaN
# Name: 1873, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1673
# WEATHER
# DISTANCE                        NaN
# Name: 1874, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1692
# WEATHER
# DISTANCE                        NaN
# Name: 1875, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1703
# WEATHER
# DISTANCE                        NaN
# Name: 1876, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1728
# WEATHER
# DISTANCE                        NaN
# Name: 1877, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1771
# WEATHER
# DISTANCE                        NaN
# Name: 1878, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1785
# WEATHER
# DISTANCE                        NaN
# Name: 1879, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             115
# KM                             1825
# WEATHER
# DISTANCE                        NaN
# Name: 1880, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             116
# KM                              224
# WEATHER
# DISTANCE                        NaN
# Name: 1881, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             116
# KM                              241
# WEATHER
# DISTANCE                        NaN
# Name: 1882, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             117
# KM                             1759
# WEATHER
# DISTANCE                        NaN
# Name: 1883, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             117
# KM                             1776
# WEATHER
# DISTANCE                        NaN
# Name: 1884, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              398
# WEATHER
# DISTANCE                        NaN
# Name: 1885, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              422
# WEATHER
# DISTANCE                        NaN
# Name: 1886, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              428
# WEATHER
# DISTANCE                        NaN
# Name: 1887, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              488
# WEATHER
# DISTANCE                        NaN
# Name: 1888, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              537
# WEATHER
# DISTANCE                        NaN
# Name: 1889, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              578
# WEATHER
# DISTANCE                        NaN
# Name: 1890, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             118
# KM                              604
# WEATHER
# DISTANCE                        NaN
# Name: 1891, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1396
# WEATHER
# DISTANCE                        NaN
# Name: 1892, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1422
# WEATHER
# DISTANCE                        NaN
# Name: 1893, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1463
# WEATHER
# DISTANCE                        NaN
# Name: 1894, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1512
# WEATHER
# DISTANCE                        NaN
# Name: 1895, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1572
# WEATHER
# DISTANCE                        NaN
# Name: 1896, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1578
# WEATHER
# DISTANCE                        NaN
# Name: 1897, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             119
# KM                             1602
# WEATHER
# DISTANCE                        NaN
# Name: 1898, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              12
# KM                               50
# WEATHER
# DISTANCE                        NaN
# Name: 1899, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             120
# KM                              127
# WEATHER
# DISTANCE                        NaN
# Name: 1900, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             121
# KM                             1873
# WEATHER
# DISTANCE                        NaN
# Name: 1901, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              567
# WEATHER
# DISTANCE                        NaN
# Name: 1902, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              590
# WEATHER
# DISTANCE                        NaN
# Name: 1903, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              604
# WEATHER
# DISTANCE                        NaN
# Name: 1904, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              610
# WEATHER
# DISTANCE                        NaN
# Name: 1905, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              660
# WEATHER
# DISTANCE                        NaN
# Name: 1906, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              668
# WEATHER
# DISTANCE                        NaN
# Name: 1907, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              669
# WEATHER
# DISTANCE                        NaN
# Name: 1908, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              679
# WEATHER
# DISTANCE                        NaN
# Name: 1909, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              680
# WEATHER
# DISTANCE                        NaN
# Name: 1910, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             122
# KM                              701
# WEATHER
# DISTANCE                        NaN
# Name: 1911, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1299
# WEATHER
# DISTANCE                        NaN
# Name: 1912, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1320
# WEATHER
# DISTANCE                        NaN
# Name: 1913, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1321
# WEATHER
# DISTANCE                        NaN
# Name: 1914, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1331
# WEATHER
# DISTANCE                        NaN
# Name: 1915, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1332
# WEATHER
# DISTANCE                        NaN
# Name: 1916, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1340
# WEATHER
# DISTANCE                        NaN
# Name: 1917, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1390
# WEATHER
# DISTANCE                        NaN
# Name: 1918, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1396
# WEATHER
# DISTANCE                        NaN
# Name: 1919, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1410
# WEATHER
# DISTANCE                        NaN
# Name: 1920, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             123
# KM                             1433
# WEATHER
# DISTANCE                        NaN
# Name: 1921, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             124
# KM                              735
# WEATHER
# DISTANCE                        NaN
# Name: 1922, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             125
# KM                             1265
# WEATHER
# DISTANCE                        NaN
# Name: 1923, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             126
# KM                               74
# WEATHER
# DISTANCE                        NaN
# Name: 1924, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             127
# KM                             1926
# WEATHER
# DISTANCE                        NaN
# Name: 1925, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             128
# KM                              599
# WEATHER
# DISTANCE                        NaN
# Name: 1926, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             129
# KM                             1401
# WEATHER
# DISTANCE                        NaN
# Name: 1927, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              13
# KM                             1950
# WEATHER
# DISTANCE                        NaN
# Name: 1928, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             130
# KM                              667
# WEATHER
# DISTANCE                        NaN
# Name: 1929, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             130
# KM                              870
# WEATHER
# DISTANCE                        NaN
# Name: 1930, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             131
# KM                             1130
# WEATHER
# DISTANCE                        NaN
# Name: 1931, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             131
# KM                             1333
# WEATHER
# DISTANCE                        NaN
# Name: 1932, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             132
# KM                              655
# WEATHER
# DISTANCE                        NaN
# Name: 1933, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             132
# KM                              675
# WEATHER
# DISTANCE                        NaN
# Name: 1934, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             133
# KM                             1325
# WEATHER
# DISTANCE                        NaN
# Name: 1935, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             133
# KM                             1345
# WEATHER
# DISTANCE                        NaN
# Name: 1936, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             134
# KM                              108
# WEATHER
# DISTANCE                        NaN
# Name: 1937, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             134
# KM                              130
# WEATHER
# DISTANCE                        NaN
# Name: 1938, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             134
# KM                              226
# WEATHER
# DISTANCE                        NaN
# Name: 1939, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             134
# KM                               75
# WEATHER
# DISTANCE                        NaN
# Name: 1940, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             134
# KM                               85
# WEATHER
# DISTANCE                        NaN
# Name: 1941, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             135
# KM                             1774
# WEATHER
# DISTANCE                        NaN
# Name: 1942, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             135
# KM                             1870
# WEATHER
# DISTANCE                        NaN
# Name: 1943, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             135
# KM                             1892
# WEATHER
# DISTANCE                        NaN
# Name: 1944, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             135
# KM                             1915
# WEATHER
# DISTANCE                        NaN
# Name: 1945, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             135
# KM                             1925
# WEATHER
# DISTANCE                        NaN
# Name: 1946, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             136
# KM                              226
# WEATHER
# DISTANCE                        NaN
# Name: 1947, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             137
# KM                             1774
# WEATHER
# DISTANCE                        NaN
# Name: 1948, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             138
# KM                              513
# WEATHER
# DISTANCE                        NaN
# Name: 1949, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             138
# KM                              533
# WEATHER
# DISTANCE                        NaN
# Name: 1950, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             139
# KM                             1467
# WEATHER
# DISTANCE                        NaN
# Name: 1951, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             139
# KM                             1487
# WEATHER
# DISTANCE                        NaN
# Name: 1952, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1045
# WEATHER
# DISTANCE                        NaN
# Name: 1953, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1070
# WEATHER
# DISTANCE                        NaN
# Name: 1954, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1073
# WEATHER
# DISTANCE                        NaN
# Name: 1955, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1100
# WEATHER
# DISTANCE                        NaN
# Name: 1956, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1102
# WEATHER
# DISTANCE                        NaN
# Name: 1957, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1127
# WEATHER
# DISTANCE                        NaN
# Name: 1958, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1145
# WEATHER
# DISTANCE                        NaN
# Name: 1959, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1177
# WEATHER
# DISTANCE                        NaN
# Name: 1960, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1239
# WEATHER
# DISTANCE                        NaN
# Name: 1961, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                             1282
# WEATHER
# DISTANCE                        NaN
# Name: 1962, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                              845
# WEATHER
# DISTANCE                        NaN
# Name: 1963, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                              901
# WEATHER
# DISTANCE                        NaN
# Name: 1964, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                              923
# WEATHER
# DISTANCE                        NaN
# Name: 1965, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                              956
# WEATHER
# DISTANCE                        NaN
# Name: 1966, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              14
# KM                              973
# WEATHER
# DISTANCE                        NaN
# Name: 1967, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             140
# KM                              584
# WEATHER
# DISTANCE                        NaN
# Name: 1968, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             140
# KM                              592
# WEATHER
# DISTANCE                        NaN
# Name: 1969, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             141
# KM                             1408
# WEATHER
# DISTANCE                        NaN
# Name: 1970, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             141
# KM                             1416
# WEATHER
# DISTANCE                        NaN
# Name: 1971, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             142
# KM                              462
# WEATHER
# DISTANCE                        NaN
# Name: 1972, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             142
# KM                              503
# WEATHER
# DISTANCE                        NaN
# Name: 1973, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             143
# KM                             1497
# WEATHER
# DISTANCE                        NaN
# Name: 1974, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             143
# KM                             1538
# WEATHER
# DISTANCE                        NaN
# Name: 1975, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             143
# KM                             1558
# WEATHER
# DISTANCE                        NaN
# Name: 1976, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             144
# KM                              813
# WEATHER
# DISTANCE                        NaN
# Name: 1977, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             145
# KM                             1187
# WEATHER
# DISTANCE                        NaN
# Name: 1978, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1050
# WEATHER
# DISTANCE                        NaN
# Name: 1979, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1074
# WEATHER
# DISTANCE                        NaN
# Name: 1980, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1095
# WEATHER
# DISTANCE                        NaN
# Name: 1981, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1118
# WEATHER
# DISTANCE                        NaN
# Name: 1982, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1174
# WEATHER
# DISTANCE                        NaN
# Name: 1983, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1186
# WEATHER
# DISTANCE                        NaN
# Name: 1984, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1194
# WEATHER
# DISTANCE                        NaN
# Name: 1985, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1250
# WEATHER
# DISTANCE                        NaN
# Name: 1986, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1366
# WEATHER
# DISTANCE                        NaN
# Name: 1987, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1401
# WEATHER
# DISTANCE                        NaN
# Name: 1988, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1445
# WEATHER
# DISTANCE                        NaN
# Name: 1989, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1473
# WEATHER
# DISTANCE                        NaN
# Name: 1990, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1488
# WEATHER
# DISTANCE                        NaN
# Name: 1991, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1494
# WEATHER
# DISTANCE                        NaN
# Name: 1992, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1497
# WEATHER
# DISTANCE                        NaN
# Name: 1993, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1504
# WEATHER
# DISTANCE                        NaN
# Name: 1994, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1549
# WEATHER
# DISTANCE                        NaN
# Name: 1995, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1612
# WEATHER
# DISTANCE                        NaN
# Name: 1996, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1613
# WEATHER
# DISTANCE                        NaN
# Name: 1997, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1656
# WEATHER
# DISTANCE                        NaN
# Name: 1998, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1657
# WEATHER
# DISTANCE                        NaN
# Name: 1999, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1660
# WEATHER
# DISTANCE                        NaN
# Name: 2000, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                             1679
# WEATHER
# DISTANCE                        NaN
# Name: 2001, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              811
# WEATHER
# DISTANCE                        NaN
# Name: 2002, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              876
# WEATHER
# DISTANCE                        NaN
# Name: 2003, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              904
# WEATHER
# DISTANCE                        NaN
# Name: 2004, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              919
# WEATHER
# DISTANCE                        NaN
# Name: 2005, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              925
# WEATHER
# DISTANCE                        NaN
# Name: 2006, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              939
# WEATHER
# DISTANCE                        NaN
# Name: 2007, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              990
# WEATHER
# DISTANCE                        NaN
# Name: 2008, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             146
# KM                              997
# WEATHER
# DISTANCE                        NaN
# Name: 2009, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             147
# KM                             1003
# WEATHER
# DISTANCE                        NaN
# Name: 2010, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             147
# KM                             1010
# WEATHER
# DISTANCE                        NaN
# Name: 2011, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             147
# KM                             1061
# WEATHER
# DISTANCE                        NaN
# Name: 2012, dtype: object
# NON PRESENTE
# ...
# KM                              719
# WEATHER
# DISTANCE                        NaN
# Name: 2486, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             269
# KM                             1281
# WEATHER
# DISTANCE                        NaN
# Name: 2487, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              27
# KM                              527
# WEATHER
# DISTANCE                        NaN
# Name: 2488, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              27
# KM                              545
# WEATHER
# DISTANCE                        NaN
# Name: 2489, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             270
# KM                              688
# WEATHER
# DISTANCE                        NaN
# Name: 2490, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             271
# KM                             1312
# WEATHER
# DISTANCE                        NaN
# Name: 2491, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             272
# KM                               65
# WEATHER
# DISTANCE                        NaN
# Name: 2492, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             272
# KM                               78
# WEATHER
# DISTANCE                        NaN
# Name: 2493, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             273
# KM                             1922
# WEATHER
# DISTANCE                        NaN
# Name: 2494, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             273
# KM                             1935
# WEATHER
# DISTANCE                        NaN
# Name: 2495, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             274
# KM                              780
# WEATHER
# DISTANCE                        NaN
# Name: 2496, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             274
# KM                              834
# WEATHER
# DISTANCE                        NaN
# Name: 2497, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             275
# KM                             1166
# WEATHER
# DISTANCE                        NaN
# Name: 2498, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             275
# KM                             1220
# WEATHER
# DISTANCE                        NaN
# Name: 2499, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             276
# KM                              754
# WEATHER
# DISTANCE                        NaN
# Name: 2500, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             277
# KM                             1246
# WEATHER
# DISTANCE                        NaN
# Name: 2501, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             278
# KM                              686
# WEATHER
# DISTANCE                        NaN
# Name: 2502, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             279
# KM                             1314
# WEATHER
# DISTANCE                        NaN
# Name: 2503, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              28
# KM                             1455
# WEATHER
# DISTANCE                        NaN
# Name: 2504, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              28
# KM                             1473
# WEATHER
# DISTANCE                        NaN
# Name: 2505, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             280
# KM                              617
# WEATHER
# DISTANCE                        NaN
# Name: 2506, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             281
# KM                             1383
# WEATHER
# DISTANCE                        NaN
# Name: 2507, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             282
# KM                              374
# WEATHER
# DISTANCE                        NaN
# Name: 2508, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             282
# KM                              443
# WEATHER
# DISTANCE                        NaN
# Name: 2509, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             283
# KM                             1557
# WEATHER
# DISTANCE                        NaN
# Name: 2510, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             283
# KM                             1626
# WEATHER
# DISTANCE                        NaN
# Name: 2511, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             284
# KM                              744
# WEATHER
# DISTANCE                        NaN
# Name: 2512, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             285
# KM                             1256
# WEATHER
# DISTANCE                        NaN
# Name: 2513, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             286
# KM                              854
# WEATHER
# DISTANCE                        NaN
# Name: 2514, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             287
# KM                             1146
# WEATHER
# DISTANCE                        NaN
# Name: 2515, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             288
# KM                              524
# WEATHER
# DISTANCE                        NaN
# Name: 2516, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             289
# KM                             1476
# WEATHER
# DISTANCE                        NaN
# Name: 2517, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                              29
# KM                              275
# WEATHER
# DISTANCE                        NaN
# Name: 2518, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             290
# KM                              299
# WEATHER
# DISTANCE                        NaN
# Name: 2519, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             291
# KM                             1701
# WEATHER
# DISTANCE                        NaN
# Name: 2520, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              743
# WEATHER
# DISTANCE                        NaN
# Name: 2521, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              761
# WEATHER
# DISTANCE                        NaN
# Name: 2522, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              767
# WEATHER
# DISTANCE                        NaN
# Name: 2523, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              768
# WEATHER
# DISTANCE                        NaN
# Name: 2524, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              775
# WEATHER
# DISTANCE                        NaN
# Name: 2525, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              776
# WEATHER
# DISTANCE                        NaN
# Name: 2526, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              782
# WEATHER
# DISTANCE                        NaN
# Name: 2527, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              789
# WEATHER
# DISTANCE                        NaN
# Name: 2528, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             292
# KM                              792
# WEATHER
# DISTANCE                        NaN
# Name: 2529, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1208
# WEATHER
# DISTANCE                        NaN
# Name: 2530, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1211
# WEATHER
# DISTANCE                        NaN
# Name: 2531, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1218
# WEATHER
# DISTANCE                        NaN
# Name: 2532, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1224
# WEATHER
# DISTANCE                        NaN
# Name: 2533, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1225
# WEATHER
# DISTANCE                        NaN
# Name: 2534, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1232
# WEATHER
# DISTANCE                        NaN
# Name: 2535, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1233
# WEATHER
# DISTANCE                        NaN
# Name: 2536, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1239
# WEATHER
# DISTANCE                        NaN
# Name: 2537, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             293
# KM                             1257
# WEATHER
# DISTANCE                        NaN
# Name: 2538, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             294
# KM                              400
# WEATHER
# DISTANCE                        NaN
# Name: 2539, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             294
# KM                              422
# WEATHER
# DISTANCE                        NaN
# Name: 2540, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             294
# KM                              459
# WEATHER
# DISTANCE                        NaN
# Name: 2541, dtype: object
# NON PRESENTE
# DATETIME_UTC    2018-09-01 01:00:00
# KEY                             295
# KM                             1541
# WEATHER
# DISTANCE                        NaN
# Name: 2542, dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-584f5c2be978> in <module>()
#      18         distance=stations[it][1]
#      19
# ---> 20         weather=weather_train_df2.loc[(station,date)].WEATHER.values[0]
#      21         it+=1
#      22         if it>= len(stations):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     868     def _getitem_tuple(self, tup):
#     869         try:
# --> 870             return self._getitem_lowerdim(tup)
#     871         except IndexingError:
#     872             pass
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     984         # instead of checking it as multiindex representation (GH 13797)
#     985         if isinstance(ax0, MultiIndex) and self.name != 'iloc':
# --> 986             result = self._handle_lowerdim_multi_index_axis0(tup)
#     987             if result is not None:
#     988                 return result
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _handle_lowerdim_multi_index_axis0(self, tup)
#     953         try:
#     954             # fast path for series or for tup devoid of slices
# --> 955             return self._get_label(tup, axis=self.axis)
#     956         except TypeError:
#     957             # slices are unhashable
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_label(self, label, axis)
#     138             raise IndexingError('no slices here, handle elsewhere')
#     139
# --> 140         return self.obj._xs(label, axis=axis)
#     141
#     142     def _get_loc(self, key, axis=None):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in xs(self, key, axis, level, drop_level)
#    3013
#    3014         else:
# -> 3015             result = self.iloc[loc]
#    3016             result.index = new_index
#    3017
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1476
#    1477             maybe_callable = com._apply_if_callable(key, self.obj)
# -> 1478             return self._getitem_axis(maybe_callable, axis=axis)
#    1479
#    1480     def _is_scalar_access(self, key):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    2078
#    2079         if isinstance(key, slice):
# -> 2080             return self._get_slice_axis(key, axis=axis)
#    2081
#    2082         if isinstance(key, list):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_slice_axis(self, slice_obj, axis)
#    2046             return obj.copy(deep=False)
#    2047
# -> 2048         slice_obj = self._convert_slice_indexer(slice_obj, axis)
#    2049         if isinstance(slice_obj, slice):
#    2050             return self._slice(slice_obj, axis=axis, kind='iloc')
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _convert_slice_indexer(self, key, axis)
#     263     def _convert_slice_indexer(self, key, axis):
#     264         # if we are accessing via lowered dim, use the last dim
# --> 265         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     266         return ax._convert_slice_indexer(key, kind=self.name)
#     267
#
# KeyboardInterrupt:
