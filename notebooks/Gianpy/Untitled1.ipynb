# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
sns.set(style="white", color_codes=True)
sns.set_context(rc={'font.family': 'sans', 'font.size': 24, 'axes.titlesize':24, 'axes.labelsize':24})
#if you want to know current working dir
os.chdir('../..')

from src.utils import *
from src.utility import merge_speed_events
import src.data as data
import src.utility as utils
from src.preprocessing.other_features import avg_speed_for_roadtype_event

# %matplotlib inline

# %%
speeds_train = pd.read_csv(resources_path('dataset', 'preprocessed', 'speeds_train_imputed_time.csv.gz'))
speeds_test = pd.read_csv(resources_path('dataset', 'preprocessed', 'speeds_test_imputed_time.csv.gz'))
speeds_2019 = pd.read_csv(resources_path('dataset', 'preprocessed', 'speeds_2019_imputed_time.csv.gz'))
print(speeds_train.shape, speeds_test.shape, speeds_2019.shape)
# Out:
# (11652930, 9) (3762660, 9) (438361, 9)

# %%
speeds_all = pd.concat([speeds_train, speeds_test, speeds_2019], ignore_index=True)
speeds_all.sort_values([KEY, KM, DATETIME], inplace=True)
speeds_all.drop_duplicates([KEY, KM, DATETIME], inplace=True)
speeds_all[DATETIME] = pd.to_datetime(speeds_all[DATETIME])
speeds_all.shape
# Out:
# (15823003, 9)

# %%
X_df = data.base_dataset(mode='full')
X_df.shape
# Out:
# caching resources/dataset/preprocessed/full/train/base_dataset.csv.gz
# (27545, 60)

# %%
print(X_df.columns)
X_df.describe()
# Out:
# Index(['event_index', 'KEY', 'KM', 'EMERGENCY_LANE', 'LANES', 'ROAD_TYPE',
#        'EVENT_DETAIL', 'EVENT_TYPE', 'DATETIME_UTC_-4', 'DATETIME_UTC_-3',
#        'DATETIME_UTC_-2', 'DATETIME_UTC_-1', 'DATETIME_UTC_y_0',
#        'DATETIME_UTC_y_1', 'DATETIME_UTC_y_2', 'DATETIME_UTC_y_3',
#        'SPEED_AVG_-4', 'SPEED_AVG_-3', 'SPEED_AVG_-2', 'SPEED_AVG_-1',
#        'SPEED_AVG_Y_0', 'SPEED_AVG_Y_1', 'SPEED_AVG_Y_2', 'SPEED_AVG_Y_3',
#        'SPEED_SD_-4', 'SPEED_SD_-3', 'SPEED_SD_-2', 'SPEED_SD_-1',
#        'SPEED_MAX_-4', 'SPEED_MAX_-3', 'SPEED_MAX_-2', 'SPEED_MAX_-1',
#        'SPEED_MIN_-4', 'SPEED_MIN_-3', 'SPEED_MIN_-2', 'SPEED_MIN_-1',
#        'N_VEHICLES_-4', 'N_VEHICLES_-3', 'N_VEHICLES_-2', 'N_VEHICLES_-1',
#        'WEATHER_-4', 'WEATHER_-3', 'WEATHER_-2', 'WEATHER_-1', 'DISTANCE_-4',
#        'DISTANCE_-3', 'DISTANCE_-2', 'DISTANCE_-1', 'TEMPERATURE_-4',
#        'TEMPERATURE_-3', 'TEMPERATURE_-2', 'TEMPERATURE_-1',
#        'MIN_TEMPERATURE_-4', 'MIN_TEMPERATURE_-3', 'MIN_TEMPERATURE_-2',
#        'MIN_TEMPERATURE_-1', 'MAX_TEMPERATURE_-4', 'MAX_TEMPERATURE_-3',
#        'MAX_TEMPERATURE_-2', 'MAX_TEMPERATURE_-1'],
#       dtype='object')
#         event_index           KEY            KM  EMERGENCY_LANE         LANES  \
# count  27545.000000  27545.000000  27545.000000    27545.000000  27545.000000
# mean   29208.569468    198.094137    600.053984        0.279506      1.704738
# std    12723.926453    178.988736    358.768360        0.448765      0.751309
# min        1.000000      0.000000     17.000000        0.000000      1.000000
# 25%    21493.000000     25.000000    363.000000        0.000000      1.000000
# 50%    30638.000000    150.000000    576.000000        0.000000      2.000000
# 75%    38611.000000    334.000000    750.000000        1.000000      2.000000
# max    47850.000000    578.000000   1997.000000        1.000000      3.000000
#
#           ROAD_TYPE  EVENT_DETAIL  SPEED_AVG_-4  SPEED_AVG_-3  SPEED_AVG_-2  \
# count  27545.000000  27545.000000  13277.000000  13321.000000  13336.000000
# mean       0.358613     23.651988    185.924849    185.133403    183.973377
# std        0.589432     21.902800     33.788831     34.116540     34.933422
# min        0.000000     -1.000000     59.866000     63.911000     63.911000
# 25%        0.000000      6.000000    162.183211    161.487432    159.777500
# 50%        0.000000     15.000000    189.774368    188.766667    187.542771
# 75%        1.000000     44.000000    212.359120    211.787684    211.280811
# max        2.000000     86.000000    295.831622    283.097806    298.556174
#
#        ...  TEMPERATURE_-2  TEMPERATURE_-1  MIN_TEMPERATURE_-4  \
# count  ...    18337.000000    18326.000000        18346.000000
# mean   ...       13.238098       13.247845           10.434863
# std    ...        7.956903        7.981672            7.191765
# min    ...      -16.000000      -16.000000          -17.000000
# 25%    ...        8.000000        8.000000            5.000000
# 50%    ...       14.000000       14.000000           11.000000
# 75%    ...       19.000000       19.000000           16.000000
# max    ...       36.000000       36.000000           28.000000
#
#        MIN_TEMPERATURE_-3  MIN_TEMPERATURE_-2  MIN_TEMPERATURE_-1  \
# count        18331.000000        18337.000000        18326.000000
# mean            10.420053           10.398429           10.377169
# std              7.207014            7.221800            7.230031
# min            -17.000000          -17.000000          -17.000000
# 25%              5.000000            5.000000            5.000000
# 50%             11.000000           11.000000           11.000000
# 75%             16.000000           16.000000           16.000000
# max             28.000000           29.000000           29.000000
#
#        MAX_TEMPERATURE_-4  MAX_TEMPERATURE_-3  MAX_TEMPERATURE_-2  \
# count        18346.000000        18331.000000        18337.000000
# mean            14.486537           14.488571           14.472651
# std              7.999827            8.015990            8.038148
# min            -15.000000          -15.000000          -15.000000
# 25%              9.000000            9.000000            9.000000
# 50%             15.000000           15.000000           15.000000
# 75%             20.000000           20.000000           20.000000
# max             41.000000           41.000000           41.000000
#
#        MAX_TEMPERATURE_-1
# count        18326.000000
# mean            14.487722
# std              8.036155
# min            -15.000000
# 25%              9.000000
# 50%             15.000000
# 75%             20.000000
# max             41.000000
#
# [8 rows x 47 columns]

# %%
window_len = sum(X_df.columns.str.match('^SPEED_AVG_-.*$')*1)
for i in range(1, window_len+1):
    time = 'DATETIME_UTC_-' + str(i)
    speed_avg = 'SPEED_AVG_-' + str(i)
    speed_max = 'SPEED_MAX_-' + str(i)
    speed_min = 'SPEED_MIN_-' + str(i)
    speed_std = 'SPEED_SD_-' + str(i)
    n_cars = 'N_VEHICLES_-' + str(i)
    X_df[time] = pd.to_datetime(X_df[time])

    X_df.drop(columns=[speed_avg, speed_max, speed_min, speed_std, n_cars], inplace=True)
    X_df = pd.merge(X_df, speeds_all[[KEY, KM, DATETIME, SPEED_AVG, SPEED_MAX, SPEED_MIN, SPEED_SD, N_CARS]],
                    left_on=[KEY, KM, time], right_on=[KEY, KM, DATETIME], how='left')
    X_df.rename(columns={SPEED_AVG: speed_avg, SPEED_MAX: speed_max, SPEED_MIN: speed_min, SPEED_SD: speed_std, N_CARS: n_cars}, inplace=True)

# %%
X_df.describe()
# Out:
#         event_index           KEY            KM  EMERGENCY_LANE         LANES  \
# count  27545.000000  27545.000000  27545.000000    27545.000000  27545.000000
# mean   29208.569468    198.094137    600.053984        0.279506      1.704738
# std    12723.926453    178.988736    358.768360        0.448765      0.751309
# min        1.000000      0.000000     17.000000        0.000000      1.000000
# 25%    21493.000000     25.000000    363.000000        0.000000      1.000000
# 50%    30638.000000    150.000000    576.000000        0.000000      2.000000
# 75%    38611.000000    334.000000    750.000000        1.000000      2.000000
# max    47850.000000    578.000000   1997.000000        1.000000      3.000000
#
#           ROAD_TYPE  EVENT_DETAIL  SPEED_AVG_Y_0  SPEED_AVG_Y_1  \
# count  27545.000000  27545.000000   13425.000000   13479.000000
# mean       0.358613     23.651988     182.252560     182.202198
# std        0.589432     21.902800      36.016595      36.232696
# min        0.000000     -1.000000      61.484000      59.866000
# 25%        0.000000      6.000000     157.792998     157.542879
# 50%        0.000000     15.000000     186.173277     186.077479
# 75%        1.000000     44.000000     210.638053     210.483260
# max        2.000000     86.000000     285.341042     292.534400
#
#        SPEED_AVG_Y_2  ...  SPEED_AVG_-3  SPEED_MAX_-3  SPEED_MIN_-3  \
# count   12897.000000  ...  13779.000000  13779.000000  13779.000000
# mean      181.922960  ...    184.820312    250.379297    125.299999
# std        36.023743  ...     34.163939     57.672978     36.066503
# min        60.675000  ...     63.911000     66.338000     59.866000
# 25%       157.280759  ...    160.623273    208.722000    100.316000
# 50%       184.990546  ...    188.011600    252.408000    131.058000
# 75%       210.224429  ...    211.641069    289.622000    152.092000
# max       286.937591  ...    378.612000    470.838000    367.286000
#
#         SPEED_SD_-3  N_VEHICLES_-3  SPEED_AVG_-4  SPEED_MAX_-4  SPEED_MIN_-4  \
# count  13779.000000   13779.000000  13715.000000  13715.000000  13715.000000
# mean      23.506733     252.892341    185.674353    250.913814    126.319390
# std        8.767394     320.471272     33.835603     57.412213     35.782251
# min        0.000000       2.000000     59.866000     59.866000     59.866000
# 25%       17.516894      41.000000    161.493491    208.722000    101.934000
# 50%       23.217494     108.000000    189.066296    254.026000    132.676000
# 75%       28.822014     324.500000    212.223947    292.858000    152.092000
# max      106.215002    1518.000000    297.924545    470.838000    278.296000
#
#         SPEED_SD_-4  N_VEHICLES_-4
# count  13715.000000   13715.000000
# mean      23.514246     250.053152
# std        8.994007     317.529297
# min        0.000000       2.000000
# 25%       17.472763      41.000000
# 50%       23.293109     108.000000
# 75%       28.874900     319.500000
# max      203.649581    1547.000000
#
# [8 rows x 47 columns]
