# %%
# Imports
import pandas as pd
import matplotlib.pyplot as plt
import os
import seaborn as sns
import numpy as np
from sklearn.model_selection import train_test_split
sns.set(style="white", color_codes=True)
sns.set_context(rc={'font.family': 'sans', 'font.size': 24, 'axes.titlesize':24, 'axes.labelsize':24})
#if you want to know current working dir
os.chdir('../..')

from src.utils import *
from src.utility import merge_speed_events
import src.data as data
import src.utility as utils
from src.preprocessing.other_features import avg_speed_for_roadtype_event

# %matplotlib inline

# %%
sub = pd.read_csv('/Users/gianpaolo/Downloads/submission_multioutput_def_TRUE.csv')
sensors = data.sensors().drop_duplicates()
# Out:
# caching resources/dataset/preprocessed/sensors.csv.gz

# %%
sub = pd.merge(sub, sensors, on=[KEY, KM])

# %%
aa = sub.sort_values([KEY, KM, 'PREDICTION_STEP'])
aa[aa.ROAD_TYPE == 0].head(200)
# Out:
#      KEY   KM         DATETIME_UTC  PREDICTION_STEP   SPEED_AVG  \
# 202   43  573  2019-01-18 16:15:00                0  190.006810
# 203   43  573  2019-01-18 16:30:00                1  189.759229
# 204   43  573  2019-01-18 16:45:00                2  189.434673
# 205   43  588  2019-01-04 11:15:00                0  214.946874
# 206   43  588  2019-01-04 11:30:00                1  216.073533
# 207   43  588  2019-01-04 11:45:00                2  216.249370
# 208   43  588  2019-01-04 12:00:00                3  220.192158
# 209   43  594  2019-01-06 15:45:00                0  227.238495
# 210   43  594  2019-01-06 16:00:00                1  228.800770
# 211   43  594  2019-01-06 16:15:00                2  230.557474
# 212   43  594  2019-01-06 16:30:00                3  228.152489
# 213   46   72  2019-01-01 19:15:00                0  133.401572
# 214   46   72  2019-01-01 19:30:00                1  132.120758
# 215   46   72  2019-01-01 19:45:00                2  128.493895
# ...

# %%
sub.head()
# Out:
#    KEY   KM         DATETIME_UTC  PREDICTION_STEP   SPEED_AVG  EMERGENCY_LANE  \
# 0    0  333  2019-01-07 08:00:00                0  233.845579               1
# 1    0  333  2019-01-07 08:15:00                1  233.845860               1
# 2    0  333  2019-01-07 08:30:00                2  234.907502               1
# 3    0  333  2019-01-07 08:45:00                3  234.893784               1
# 4    0  337  2019-01-07 08:00:00                0  213.330420               1
#
#    LANES  ROAD_TYPE
# 0      2          1
# 1      2          1
# 2      2          1
# 3      2          1
# 4      2          1
